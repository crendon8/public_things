# %%
from mini_fake_data import make_fake_frames
from mini_symbol_single import plot_single_symbol
series = [
    {"label": "NYSE px0", "bid": "NYSE.ABC_bid_px0", "ask": "NYSE.ABC_ask_px0"},
    {"label": "OTHER px1", "bid": "OTHER.ABC_bid_px1", "ask": "OTHER.ABC_ask_px1"},
    {"label": "Internal FV", "bid": "INTERNAL.ABC_FV_bid", "ask": "INTERNAL.ABC_FV_ask", "mid": "INTERNAL.ABC_FV_mid"},
]

# %%
fills_df, market_df = make_fake_frames(days=2)
fills_df.head()

# %%
fig = plot_single_symbol(fills_df, market_df, "ABC", market_series=series)
fig
