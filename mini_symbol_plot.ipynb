# %%
from mini_fake_data import make_fake_frames
from mini_symbol_plot import plot_market

# %%
fills_df, market_df = make_fake_frames(days=3, freq='10min')
fills_df.head()

# %%
fig = plot_market(fills_df, market_df)
fig
