# %% [markdown]
# # Symbol market plot demo
#
# Generate synthetic fill + market data and visualize the Plotly chart directly from the notebook.
#
# * Run the import cell to pull helpers from `symbol_market_plot.py`.
# * Execute the data cell to create the fake dataframes.
# * Finally, run the plotting cell to render the dropdown chart inline.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install --upgrade nbformat

# %%
from symbol_market_plot import SymbolMarketPlotter, create_fake_dataframes

# %%
fills_df, market_df = create_fake_dataframes()
plotter = SymbolMarketPlotter(fills_df, market_df)
fills_df.head()
# Out:
#   symbol               rxTime  OrderPrice  FillSize     TriggerName
# 0    DEF  1704194606000000000  105.656125       645  DEF_strategy_3
# 1    ABC  1704195481000000000   93.224500       159  ABC_strategy_2
# 2    DEF  1704197939000000000  104.680512       432  DEF_strategy_1
# 3    ABC  1704200640000000000   84.753029       616  ABC_strategy_1
# 4    DEF  1704200896000000000  106.860385       679  DEF_strategy_3

# %%
plotter.display_time_filter_widget()
